# %%
# %run train.py
# Out:
# Loading train and validate samples...
# train samples 53879, validate samples 1758
# Fine-tune model: True, batch size: 32, learning reate: 0.0001, dropout keep probability: 0.8
#
# ...
